# %% [markdown]
# # Pandas
#
# Pandas provides us Series and DataFrame

# %%
import numpy as np
import matplotlib.pyplot as plt # visualization
import pandas as pd
import re
import os

# %% [markdown]
# ## Pandas Series

# %%
lst = [1, 2, 3]

s1 = pd.Series(lst)
s1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s1[0]
# Out:
# 1

# %%
lst = [1, 2, 3]

s2 = pd.Series(lst, index= ['A', 'B','C'])
s2
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
s2['A']
# Out:
# 1

# %%
s2[0]
# Out:
# 1

# %%
s2[1]
# Out:
# 2

# %%
s2[2]
# Out:
# 3

# %%
s2.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
fruits = ['Orange','Banana','Mango']
fruits = pd.Series(fruits, index=['O', 'B', 'M'])
fruits
# Out:
# O    Orange
# B    Banana
# M     Mango
# dtype: object

# %%
dct = {'name':'Asabeneh','country':'Finland','city':'Helsinki'}
s = pd.Series(dct)
s
# Out:
# name       Asabeneh
# country     Finland
# city       Helsinki
# dtype: object

# %%
s.index
# Out:
# Index(['name', 'country', 'city'], dtype='object')

# %%
s['name']
# Out:
# 'Asabeneh'

# %%
s['city']
# Out:
# 'Helsinki'

# %%
s = pd.Series(10, index = np.arange(100))
s
# Out:
# 0     10
# 1     10
# 2     10
# 3     10
# 4     10
#       ..
# 95    10
# 96    10
# 97    10
# 98    10
# 99    10
# Length: 100, dtype: int64

# %%
s = pd.Series(np.linspace(5, 20, 10))
s
# Out:
# 0     5.000000
# 1     6.666667
# 2     8.333333
# 3    10.000000
# 4    11.666667
# 5    13.333333
# 6    15.000000
# 7    16.666667
# 8    18.333333
# 9    20.000000
# dtype: float64

# %%
fruits_series = fruits.copy()

# %%
fruits_series
# Out:
# O    Orange
# B    Banana
# M     Mango
# dtype: object

# %% [markdown]
# ## DataFrames

# %%
names =  ['Asabeneh', 'David', 'John']
names = pd.Series(names)
names
# Out:
# 0    Asabeneh
# 1       David
# 2        John
# dtype: object

# %%
country =   ['Finland', 'UK', 'Sweden']
country = pd.Series(country)
country
# Out:
# 0    Finland
# 1         UK
# 2     Sweden
# dtype: object

# %%
cities = ['Helsinki', 'London','Stockholm']
cities = pd.Series(cities)
cities
# Out:
# 0     Helsinki
# 1       London
# 2    Stockholm
# dtype: object

# %% [markdown]
# ## List of lists

# %%
data = [
    ['Asabeneh', 'Finland', 'Helsink'], 
    ['David', 'UK', 'London'],
    ['John', 'Sweden', 'Stockholm']
]

df = pd.DataFrame(data, columns=['Name','Country','City'])
df
# Out:
#        Name  Country       City
# 0  Asabeneh  Finland    Helsink
# 1     David       UK     London
# 2      John   Sweden  Stockholm

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
data = [
    {'Name': 'Asabeneh', 'Country': 'Finland', 'City': 'Helsinki'},
    {'Name': 'David', 'Country': 'UK', 'City': 'London'},
    {'Name': 'John', 'Country': 'Sweden', 'City': 'Stockholm'}
]
df = pd.DataFrame(data)
df
# Out:
#        Name  Country       City
# 0  Asabeneh  Finland   Helsinki
# 1     David       UK     London
# 2      John   Sweden  Stockholm

# %% [markdown]
# ## Reading different files using Pandas
# csv, txt, tsv, json, xml, xls etc
# Now, let's read csv

# %%
df = pd.read_csv('./datasets/weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.head(15)
# Out:
#    Gender     Height      Weight
# 0    Male  73.847017  241.893563
# 1    Male  68.781904  162.310473
# 2    Male  74.110105  212.740856
# 3    Male  71.730978  220.042470
# 4    Male  69.881796  206.349801
# 5    Male  67.253016  152.212156
# 6    Male  68.785081  183.927889
# 7    Male  68.348516  167.971110
# 8    Male  67.018950  175.929440
# 9    Male  63.456494  156.399676
# 10   Male  71.195382  186.604926
# 11   Male  71.640805  213.741169
# 12   Male  64.766329  167.127461
# 13   Male  69.283070  189.446181
# 14   Male  69.243732  186.434168

# %%
df.tail()
# Out:
#       Gender     Height      Weight
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103

# %%
df.tail(15)
# Out:
#       Gender     Height      Weight
# 9985  Female  68.041065  170.514213
# 9986  Female  63.352698  141.906510
# 9987  Female  65.610243  151.169475
# 9988  Female  59.538729  121.244876
# 9989  Female  60.955084   95.686674
# 9990  Female  63.179498  141.266100
# 9991  Female  62.636675  102.853563
# 9992  Female  62.077832  138.691680
# 9993  Female  60.030434   97.687432
# 9994  Female  59.098250  110.529686
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103

# %%
df.columns
# Out:
# Index(['Gender', 'Height', 'Weight'], dtype='object')

# %%
df.shape
# Out:
# (10000, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %% [markdown]
# # Descriptive Statistics
#
# Measure of central tendency
# - mean
# - median
# - mode
#
# Measure of variability
# - Standard Deviation
# - Varience
# - min
# - max
# - range

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
df.describe(include='all')
# Out:
#         Gender        Height        Weight
# count    10000  10000.000000  10000.000000
# unique       2           NaN           NaN
# top     Female           NaN           NaN
# freq      5000           NaN           NaN
# mean       NaN     66.367560    161.440357
# std        NaN      3.847528     32.108439
# min        NaN     54.263133     64.700127
# 25%        NaN     63.505620    135.818051
# 50%        NaN     66.318070    161.212928
# 75%        NaN     69.174262    187.169525
# max        NaN     78.998742    269.989699

# %%
df.describe(include='all',  percentiles = [0.1, 0.2, 0.25, 0.5, 0.65, 0.75, 0.85])
# Out:
#         Gender        Height        Weight
# count    10000  10000.000000  10000.000000
# unique       2           NaN           NaN
# top     Female           NaN           NaN
# freq      5000           NaN           NaN
# mean       NaN     66.367560    161.440357
# std        NaN      3.847528     32.108439
# min        NaN     54.263133     64.700127
# 10%        NaN     61.412701    119.754096
# 20%        NaN     62.859007    131.118873
# 25%        NaN     63.505620    135.818051
# 50%        NaN     66.318070    161.212928
# 65%        NaN     67.998651    177.251895
# 75%        NaN     69.174262    187.169525
# 85%        NaN     70.577106    197.536443
# max        NaN     78.998742    269.989699

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df['Gender'].head(20)
# Out:
# 0     Male
# 1     Male
# 2     Male
# 3     Male
# 4     Male
# 5     Male
# 6     Male
# 7     Male
# 8     Male
# 9     Male
# 10    Male
# 11    Male
# 12    Male
# 13    Male
# 14    Male
# 15    Male
# 16    Male
# 17    Male
# 18    Male
# 19    Male
# Name: Gender, dtype: object

# %%
type(df['Gender'])
# Out:
# pandas.core.series.Series

# %%
len(df['Gender'])
# Out:
# 10000

# %%
x = df['Height']

# %%
y = df['Weight']
plt.scatter(x, y)
plt.xlabel('Weight')
plt.ylabel('Height')
plt.show()

# %%
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
data = [
    {"Name": "Asabeneh", "Country":"Finland","City":"Helsinki"},
    {"Name": "David", "Country":"UK","City":"London"},
    {"Name": "John", "Country":"Sweden","City":"Stockholm"},
    {"Name": "Eyob", "Country":"Finland","City":"Espoo"},
    {"Name": "Pawel", "Country":"Poland","City":"Warsaw"},
    {"Name": "Mahlet", "Country":"Ethiopia","City":"Addis Ababa"},
    {"Name": "Thomas", "Country":"Ethiopia","City":"Bahir Dar"},
    {"Name": "Lidiya", "Country":float('NaN'),"City":float('NaN')},
]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        Name   Country         City
# 0  Asabeneh   Finland     Helsinki
# 1     David        UK       London
# 2      John    Sweden    Stockholm
# 3      Eyob   Finland        Espoo
# 4     Pawel    Poland       Warsaw
# 5    Mahlet  Ethiopia  Addis Ababa
# 6    Thomas  Ethiopia    Bahir Dar
# 7    Lidiya       NaN          NaN

# %%
df['Name'] = df['Name'].str.upper()

# %%
df
# Out:
#        Name   Country         City
# 0  ASABENEH   Finland     Helsinki
# 1     DAVID        UK       London
# 2      JOHN    Sweden    Stockholm
# 3      EYOB   Finland        Espoo
# 4     PAWEL    Poland       Warsaw
# 5    MAHLET  Ethiopia  Addis Ababa
# 6    THOMAS  Ethiopia    Bahir Dar
# 7    LIDIYA       NaN          NaN

# %%
weights = [74, 78, 68, 108, 102, 58, 52, float('NaN')]

# %%
df['Weight'] = weights

# %%
df
# Out:
#        Name   Country         City  Weight
# 0  ASABENEH   Finland     Helsinki    74.0
# 1     DAVID        UK       London    78.0
# 2      JOHN    Sweden    Stockholm    68.0
# 3      EYOB   Finland        Espoo   108.0
# 4     PAWEL    Poland       Warsaw   102.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0
# 7    LIDIYA       NaN          NaN     NaN

# %%
heights = [173, 175, 169, 173, 195,168, 170, float('NaN')]
df['Height'] = heights

# %%
df
# Out:
#        Name   Country         City  Weight  Height
# 0  ASABENEH   Finland     Helsinki    74.0   173.0
# 1     DAVID        UK       London    78.0   175.0
# 2      JOHN    Sweden    Stockholm    68.0   169.0
# 3      EYOB   Finland        Espoo   108.0   173.0
# 4     PAWEL    Poland       Warsaw   102.0   195.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0   168.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0   170.0
# 7    LIDIYA       NaN          NaN     NaN     NaN

# %%
df['Height'] = df['Height'] * 0.01

# %%
df
# Out:
#        Name   Country         City  Weight  Height
# 0  ASABENEH   Finland     Helsinki    74.0    1.73
# 1     DAVID        UK       London    78.0    1.75
# 2      JOHN    Sweden    Stockholm    68.0    1.69
# 3      EYOB   Finland        Espoo   108.0    1.73
# 4     PAWEL    Poland       Warsaw   102.0    1.95
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70
# 7    LIDIYA       NaN          NaN     NaN     NaN

# %%
def calc_bmi():
    weights = df['Weight']
    heights = df['Height']
    bmi = []
    for w, h in zip(weights, heights):
        b = round(w / (h * h), 1)
        bmi.append(b)
    return bmi

bmi = calc_bmi()
print(bmi)
# Out:
# [24.7, 25.5, 23.8, 36.1, 26.8, 20.5, 18.0, nan]

# %%
# weights = df['Weight']
# heights = df['Height']

# df['bmi'] = round((weights)/(heights ** 2), 1)
# df

# %%
df['BMI'] = bmi

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7
# 1     DAVID        UK       London    78.0    1.75  25.5
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN

# %%
nums = [1, 2, 3]
values = [20, 15, 30]
ext_lst = [100, 15, 30]
for n,v,e in zip(nums,values,ext_lst):
    print(n, v,e, n * v, v ** n)
# Out:
# 1 20 100 20 20
# 2 15 15 30 225
# 3 30 30 90 27000

# %%
birth_year = ['1769', '1985', '1990', '1983', '1985','1995', '1999',float('NaN')]
df['Birth Year'] = birth_year
df['Current Year'] = 2021

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     DAVID        UK       London    78.0    1.75  25.5       1985
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1       1983
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN        NaN
#
#    Current Year
# 0          2021
# 1          2021
# 2          2021
# 3          2021
# 4          2021
# 5          2021
# 6          2021
# 7          2021

# %%
df['Birth Year'].dtype
# Out:
# dtype('O')

# %%
df['Birth Year'] = df['Birth Year'].astype(float)

# %%
ages = df['Current Year'] - df['Birth Year']
ages
# Out:
# 0    252.0
# 1     36.0
# 2     31.0
# 3     38.0
# 4     36.0
# 5     26.0
# 6     22.0
# 7      NaN
# dtype: float64

# %%
df['Age'] = ages

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    Current Year    Age
# 0          2021  252.0
# 1          2021   36.0
# 2          2021   31.0
# 3          2021   38.0
# 4          2021   36.0
# 5          2021   26.0
# 6          2021   22.0
# 7          2021    NaN

# %%
df_copied = df.copy()

# %%
df_copied
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    Current Year    Age
# 0          2021  252.0
# 1          2021   36.0
# 2          2021   31.0
# 3          2021   38.0
# 4          2021   36.0
# 5          2021   26.0
# 6          2021   22.0
# 7          2021    NaN

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    Current Year    Age
# 0          2021  252.0
# 1          2021   36.0
# 2          2021   31.0
# 3          2021   38.0
# 4          2021   36.0
# 5          2021   26.0
# 6          2021   22.0
# 7          2021    NaN

# %%
df.drop('Name', axis = 1, inplace=True)

# %%
df.drop(columns = 'Country', axis = 1)
# Out:
#           City  Weight  Height   BMI  Birth Year  Current Year    Age
# 0     Helsinki    74.0    1.73  24.7      1769.0          2021  252.0
# 1       London    78.0    1.75  25.5      1985.0          2021   36.0
# 2    Stockholm    68.0    1.69  23.8      1990.0          2021   31.0
# 3        Espoo   108.0    1.73  36.1      1983.0          2021   38.0
# 4       Warsaw   102.0    1.95  26.8      1985.0          2021   36.0
# 5  Addis Ababa    58.0    1.68  20.5      1995.0          2021   26.0
# 6    Bahir Dar    52.0    1.70  18.0      1999.0          2021   22.0
# 7          NaN     NaN     NaN   NaN         NaN          2021    NaN

# %%
df.drop(['Country','City'], axis = 1, inplace=True)

# %%
df
# Out:
#    Weight  Height   BMI  Birth Year  Current Year    Age
# 0    74.0    1.73  24.7      1769.0          2021  252.0
# 1    78.0    1.75  25.5      1985.0          2021   36.0
# 2    68.0    1.69  23.8      1990.0          2021   31.0
# 3   108.0    1.73  36.1      1983.0          2021   38.0
# 4   102.0    1.95  26.8      1985.0          2021   36.0
# 5    58.0    1.68  20.5      1995.0          2021   26.0
# 6    52.0    1.70  18.0      1999.0          2021   22.0
# 7     NaN     NaN   NaN         NaN          2021    NaN

# %%
df.drop([0, 3, 7])
# Out:
#    Weight  Height   BMI  Birth Year  Current Year   Age
# 1    78.0    1.75  25.5      1985.0          2021  36.0
# 2    68.0    1.69  23.8      1990.0          2021  31.0
# 4   102.0    1.95  26.8      1985.0          2021  36.0
# 5    58.0    1.68  20.5      1995.0          2021  26.0
# 6    52.0    1.70  18.0      1999.0          2021  22.0

# %%
df
# Out:
#    Weight  Height   BMI  Birth Year  Current Year    Age
# 0    74.0    1.73  24.7      1769.0          2021  252.0
# 1    78.0    1.75  25.5      1985.0          2021   36.0
# 2    68.0    1.69  23.8      1990.0          2021   31.0
# 3   108.0    1.73  36.1      1983.0          2021   38.0
# 4   102.0    1.95  26.8      1985.0          2021   36.0
# 5    58.0    1.68  20.5      1995.0          2021   26.0
# 6    52.0    1.70  18.0      1999.0          2021   22.0
# 7     NaN     NaN   NaN         NaN          2021    NaN

# %%
df
# Out:
#    Weight  Height   BMI  Birth Year  Current Year    Age
# 0    74.0    1.73  24.7      1769.0          2021  252.0
# 1    78.0    1.75  25.5      1985.0          2021   36.0
# 2    68.0    1.69  23.8      1990.0          2021   31.0
# 3   108.0    1.73  36.1      1983.0          2021   38.0
# 4   102.0    1.95  26.8      1985.0          2021   36.0
# 5    58.0    1.68  20.5      1995.0          2021   26.0
# 6    52.0    1.70  18.0      1999.0          2021   22.0
# 7     NaN     NaN   NaN         NaN          2021    NaN

# %%
df = df_copied

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    Current Year    Age
# 0          2021  252.0
# 1          2021   36.0
# 2          2021   31.0
# 3          2021   38.0
# 4          2021   36.0
# 5          2021   26.0
# 6          2021   22.0
# 7          2021    NaN

# %%
df.columns = df.columns.str.lower()
df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age
# 0          2021  252.0
# 1          2021   36.0
# 2          2021   31.0
# 3          2021   38.0
# 4          2021   36.0
# 5          2021   26.0
# 6          2021   22.0
# 7          2021    NaN

# %%
df.rename(
 columns={
        'birth year':'birth_year',
        'current year':'current_year'
    })
# Out:
#        name   country         city  weight  height   bmi  birth_year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current_year    age
# 0          2021  252.0
# 1          2021   36.0
# 2          2021   31.0
# 3          2021   38.0
# 4          2021   36.0
# 5          2021   26.0
# 6          2021   22.0
# 7          2021    NaN

# %%
df['country'].dtype
# Out:
# dtype('O')

# %%
df['name'].dtype
# Out:
# dtype('O')

# %%
df[['name','country','city']]
# Out:
#        name   country         city
# 0  ASABENEH   Finland     Helsinki
# 1     DAVID        UK       London
# 2      JOHN    Sweden    Stockholm
# 3      EYOB   Finland        Espoo
# 4     PAWEL    Poland       Warsaw
# 5    MAHLET  Ethiopia  Addis Ababa
# 6    THOMAS  Ethiopia    Bahir Dar
# 7    LIDIYA       NaN          NaN

# %%
df[['weight','height', 'bmi', 'age']]
# Out:
#    weight  height   bmi    age
# 0    74.0    1.73  24.7  252.0
# 1    78.0    1.75  25.5   36.0
# 2    68.0    1.69  23.8   31.0
# 3   108.0    1.73  36.1   38.0
# 4   102.0    1.95  26.8   36.0
# 5    58.0    1.68  20.5   26.0
# 6    52.0    1.70  18.0   22.0
# 7     NaN     NaN   NaN    NaN

# %%
## Boolean indexing

# %%
df[df['bmi'] <= 25]
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
#
#    current year    age
# 0          2021  252.0
# 2          2021   31.0
# 5          2021   26.0
# 6          2021   22.0

# %%
df[df['bmi'] > 25]
# Out:
#     name  country    city  weight  height   bmi  birth year  current year  \
# 1  DAVID       UK  London    78.0    1.75  25.5      1985.0          2021
# 3   EYOB  Finland   Espoo   108.0    1.73  36.1      1983.0          2021
# 4  PAWEL   Poland  Warsaw   102.0    1.95  26.8      1985.0          2021
#
#     age
# 1  36.0
# 3  38.0
# 4  36.0

# %%
df[df['country'] == 'Finland']
# Out:
#        name  country      city  weight  height   bmi  birth year  \
# 0  ASABENEH  Finland  Helsinki    74.0    1.73  24.7      1769.0
# 3      EYOB  Finland     Espoo   108.0    1.73  36.1      1983.0
#
#    current year    age
# 0          2021  252.0
# 3          2021   38.0

# %%
df[df['height'] > 1.8]
# Out:
#     name country    city  weight  height   bmi  birth year  current year   age
# 4  PAWEL  Poland  Warsaw   102.0    1.95  26.8      1985.0          2021  36.0

# %%
def classify_bmi(bmi):
    if bmi >= 30:
        return 'Obesity Range'
    elif bmi < 30 and bmi > 25:
        return 'Overweight Range'
    elif bmi < 25 and bmi >= 18.5:
        return 'Healthy Range'
    elif bmi < 18.5:
        return 'Underweight Range'

# %%
df['BMI class'] = df['bmi'].apply(lambda x: classify_bmi(x))

# %%
df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
## Accessing row
# loc

# %%
df.loc[[0]]
# Out:
#        name  country      city  weight  height   bmi  birth year  \
# 0  ASABENEH  Finland  Helsinki    74.0    1.73  24.7      1769.0
#
#    current year    age      BMI class
# 0          2021  252.0  Healthy Range

# %%
df.loc[[2]]
# Out:
#    name country       city  weight  height   bmi  birth year  current year  \
# 2  JOHN  Sweden  Stockholm    68.0    1.69  23.8      1990.0          2021
#
#     age      BMI class
# 2  31.0  Healthy Range

# %%
df.loc[:]
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
df.loc[[0, 3, 7]]
# Out:
#        name  country      city  weight  height   bmi  birth year  \
# 0  ASABENEH  Finland  Helsinki    74.0    1.73  24.7      1769.0
# 3      EYOB  Finland     Espoo   108.0    1.73  36.1      1983.0
# 7    LIDIYA      NaN       NaN     NaN     NaN   NaN         NaN
#
#    current year    age      BMI class
# 0          2021  252.0  Healthy Range
# 3          2021   38.0  Obesity Range
# 7          2021    NaN           None

# %%
df.loc[3:4]
# Out:
#     name  country    city  weight  height   bmi  birth year  current year  \
# 3   EYOB  Finland   Espoo   108.0    1.73  36.1      1983.0          2021
# 4  PAWEL   Poland  Warsaw   102.0    1.95  26.8      1985.0          2021
#
#     age         BMI class
# 3  38.0     Obesity Range
# 4  36.0  Overweight Range

# %%
data = [
    {"Name": "Asabeneh", "Country":"Finland","City":"Helsinki"},
    {"Name": "David", "Country":"UK","City":"London"},
    {"Name": "John", "Country":"Sweden","City":"Stockholm"},
    {"Name": "Eyob", "Country":"Finland","City":"Espoo"},
    {"Name": "Pawel", "Country":"Poland","City":"Warsaw"},
    {"Name": "Mahlet", "Country":"Ethiopia","City":"Addis Ababa"},
    {"Name": "Thomas", "Country":"Ethiopia","City":"Bahir Dar"},

]
df = pd.DataFrame(data, index = ['A','B','C','D','E','F','G'])

# %%
df
# Out:
#        Name   Country         City
# A  Asabeneh   Finland     Helsinki
# B     David        UK       London
# C      John    Sweden    Stockholm
# D      Eyob   Finland        Espoo
# E     Pawel    Poland       Warsaw
# F    Mahlet  Ethiopia  Addis Ababa
# G    Thomas  Ethiopia    Bahir Dar

# %%
df.loc['A']
# Out:
# Name       Asabeneh
# Country     Finland
# City       Helsinki
# Name: A, dtype: object

# %%
df.loc['B']
# Out:
# Name        David
# Country        UK
# City       London
# Name: B, dtype: object

# %%
df.loc[['A','E','F']]
# Out:
#        Name   Country         City
# A  Asabeneh   Finland     Helsinki
# E     Pawel    Poland       Warsaw
# F    Mahlet  Ethiopia  Addis Ababa

# %%
df.loc['A', 'Name']
# Out:
# 'Asabeneh'

# %%
df.loc['E','City']
# Out:
# 'Warsaw'

# %%
# iloc

# %%
df = df_copied

# %%
df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
df.iloc[1] # first row
# Out:
# name                       DAVID
# country                       UK
# city                      London
# weight                        78
# height                      1.75
# bmi                         25.5
# birth year                  1985
# current year                2021
# age                           36
# BMI class       Overweight Range
# Name: 1, dtype: object

# %%
df.iloc[[1]] # first row
# Out:
#     name country    city  weight  height   bmi  birth year  current year  \
# 1  DAVID      UK  London    78.0    1.75  25.5      1985.0          2021
#
#     age         BMI class
# 1  36.0  Overweight Range

# %%
df.iloc[1]
# Out:
# name                       DAVID
# country                       UK
# city                      London
# weight                        78
# height                      1.75
# bmi                         25.5
# birth year                  1985
# current year                2021
# age                           36
# BMI class       Overweight Range
# Name: 1, dtype: object

# %%
df.iloc[[1]]
# Out:
#     name country    city  weight  height   bmi  birth year  current year  \
# 1  DAVID      UK  London    78.0    1.75  25.5      1985.0          2021
#
#     age         BMI class
# 1  36.0  Overweight Range

# %%
df.iloc[[1, 3, 5]]
# Out:
#      name   country         city  weight  height   bmi  birth year  \
# 1   DAVID        UK       London    78.0    1.75  25.5      1985.0
# 3    EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 5  MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
#
#    current year   age         BMI class
# 1          2021  36.0  Overweight Range
# 3          2021  38.0     Obesity Range
# 5          2021  26.0     Healthy Range

# %%
df.iloc[:]
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
df.iloc[0:3]
# Out:
#        name  country       city  weight  height   bmi  birth year  \
# 0  ASABENEH  Finland   Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID       UK     London    78.0    1.75  25.5      1985.0
# 2      JOHN   Sweden  Stockholm    68.0    1.69  23.8      1990.0
#
#    current year    age         BMI class
# 0          2021  252.0     Healthy Range
# 1          2021   36.0  Overweight Range
# 2          2021   31.0     Healthy Range

# %%
df.iloc[3:]
# Out:
#      name   country         city  weight  height   bmi  birth year  \
# 3    EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4   PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5  MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6  THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7  LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year   age          BMI class
# 3          2021  38.0      Obesity Range
# 4          2021  36.0   Overweight Range
# 5          2021  26.0      Healthy Range
# 6          2021  22.0  Underweight Range
# 7          2021   NaN               None

# %%
df.iloc[lambda x: x.index % 2 == 0]
# Out:
#        name   country       city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland   Helsinki    74.0    1.73  24.7      1769.0
# 2      JOHN    Sweden  Stockholm    68.0    1.69  23.8      1990.0
# 4     PAWEL    Poland     Warsaw   102.0    1.95  26.8      1985.0
# 6    THOMAS  Ethiopia  Bahir Dar    52.0    1.70  18.0      1999.0
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 2          2021   31.0      Healthy Range
# 4          2021   36.0   Overweight Range
# 6          2021   22.0  Underweight Range

# %%
df.iloc[lambda x: x.index % 2 != 0]
# Out:
#      name   country         city  weight  height   bmi  birth year  \
# 1   DAVID        UK       London    78.0    1.75  25.5      1985.0
# 3    EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 5  MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 7  LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year   age         BMI class
# 1          2021  36.0  Overweight Range
# 3          2021  38.0     Obesity Range
# 5          2021  26.0     Healthy Range
# 7          2021   NaN              None

# %%
df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
df.loc[0, 'birth year']
# Out:
# 1769.0

# %%
df.iloc[0, 6]
# Out:
# 1769.0

# %%
df.iloc[0:3]
# Out:
#        name  country       city  weight  height   bmi  birth year  \
# 0  ASABENEH  Finland   Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID       UK     London    78.0    1.75  25.5      1985.0
# 2      JOHN   Sweden  Stockholm    68.0    1.69  23.8      1990.0
#
#    current year    age         BMI class
# 0          2021  252.0     Healthy Range
# 1          2021   36.0  Overweight Range
# 2          2021   31.0     Healthy Range

# %%
df.iloc[0:3, 0:4]
# Out:
#        name  country       city  weight
# 0  ASABENEH  Finland   Helsinki    74.0
# 1     DAVID       UK     London    78.0
# 2      JOHN   Sweden  Stockholm    68.0

# %%
df.iloc[0:, 3:9]
# Out:
#    weight  height   bmi  birth year  current year    age
# 0    74.0    1.73  24.7      1769.0          2021  252.0
# 1    78.0    1.75  25.5      1985.0          2021   36.0
# 2    68.0    1.69  23.8      1990.0          2021   31.0
# 3   108.0    1.73  36.1      1983.0          2021   38.0
# 4   102.0    1.95  26.8      1985.0          2021   36.0
# 5    58.0    1.68  20.5      1995.0          2021   26.0
# 6    52.0    1.70  18.0      1999.0          2021   22.0
# 7     NaN     NaN   NaN         NaN          2021    NaN

# %%
df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1769.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
mean = df.drop([7]).iloc[1:]['birth year'].mean()
mean
# Out:
# 1989.5

# %%
df.iloc[0, 6] = round(mean)

# %%
df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
joined_df = pd.concat([df, df])
joined_df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
joined_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# dtype: bool

# %%
joined_df.drop_duplicates()
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
joined_df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
joined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 7
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          16 non-null     object
#  1   country       14 non-null     object
#  2   city          14 non-null     object
#  3   weight        14 non-null     float64
#  4   height        14 non-null     float64
#  5   bmi           14 non-null     float64
#  6   birth year    14 non-null     float64
#  7   current year  16 non-null     int64
#  8   age           14 non-null     float64
#  9   BMI class     14 non-null     object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.4+ KB

# %%
joined_df['weight'].fillna(75, inplace=True)

# %%
joined_df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN    75.0     NaN   NaN         NaN
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 7    LIDIYA       NaN          NaN    75.0     NaN   NaN         NaN
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range
# 7          2021    NaN               None

# %%
joined_df.drop_duplicates(inplace=True)
joined_df.drop([7], axis=0, inplace=True)
joined_df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range

# %%
joined_df.describe()
# Out:
#            weight    height        bmi   birth year  current year         age
# count    7.000000  7.000000   7.000000     7.000000           7.0    7.000000
# mean    77.142857  1.747143  25.057143  1989.571429        2021.0   63.000000
# std     21.066787  0.092864   5.736682     5.826867           0.0   83.544399
# min     52.000000  1.680000  18.000000  1983.000000        2021.0   22.000000
# 25%     63.000000  1.695000  22.150000  1985.000000        2021.0   28.500000
# 50%     74.000000  1.730000  24.700000  1990.000000        2021.0   36.000000
# 75%     90.000000  1.740000  26.150000  1992.500000        2021.0   37.000000
# max    108.000000  1.950000  36.100000  1999.000000        2021.0  252.000000

# %%
joined_df.corr()
# Out:
#                 weight    height       bmi  birth year  current year       age
# weight        1.000000  0.644298  0.912597   -0.905028           NaN -0.002651
# height        0.644298  1.000000  0.275980   -0.513936           NaN -0.045543
# bmi           0.912597  0.275980  1.000000   -0.870201           NaN  0.033245
# birth year   -0.905028 -0.513936 -0.870201    1.000000           NaN -0.037318
# current year       NaN       NaN       NaN         NaN           NaN       NaN
# age          -0.002651 -0.045543  0.033245   -0.037318           NaN  1.000000

# %%
joined_df.mean()
# Out:
# weight            77.142857
# height             1.747143
# bmi               25.057143
# birth year      1989.571429
# current year    2021.000000
# age               63.000000
# dtype: float64

# %%
joined_df.median()
# Out:
# weight            74.00
# height             1.73
# bmi               24.70
# birth year      1990.00
# current year    2021.00
# age               36.00
# dtype: float64

# %%
joined_df.std()
# Out:
# weight          21.066787
# height           0.092864
# bmi              5.736682
# birth year       5.826867
# current year     0.000000
# age             83.544399
# dtype: float64

# %%
joined_df.var()
# Out:
# weight           443.809524
# height             0.008624
# bmi               32.909524
# birth year        33.952381
# current year       0.000000
# age             6979.666667
# dtype: float64

# %%
joined_df['country'].mode()
# Out:
# 0    Ethiopia
# 1     Finland
# dtype: object

# %%
joined_df
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
#
#    current year    age          BMI class
# 0          2021  252.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 4          2021   36.0   Overweight Range
# 5          2021   26.0      Healthy Range
# 6          2021   22.0  Underweight Range

# %%
joined_df.value_counts('country')
# Out:
# country
# Finland     2
# Ethiopia    2
# UK          1
# Sweden      1
# Poland      1
# dtype: int64

# %%
joined_df.groupby('country', sort = True).mean()
# Out:
#           weight  height    bmi  birth year  current year    age
# country
# Ethiopia    55.0    1.69  19.25      1997.0          2021   24.0
# Finland     91.0    1.73  30.40      1986.5          2021  145.0
# Poland     102.0    1.95  26.80      1985.0          2021   36.0
# Sweden      68.0    1.69  23.80      1990.0          2021   31.0
# UK          78.0    1.75  25.50      1985.0          2021   36.0

# %%
joined_df.sort_values('city', ascending=False)
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
#
#    current year    age          BMI class
# 4          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 0          2021  252.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 6          2021   22.0  Underweight Range
# 5          2021   26.0      Healthy Range

# %%
df.sort_values('city', ascending=False, na_position='first')
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
#
#    current year    age          BMI class
# 7          2021    NaN               None
# 4          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 0          2021  252.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 6          2021   22.0  Underweight Range
# 5          2021   26.0      Healthy Range

# %%
df.sort_values('city', ascending=False, na_position='last')
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 4          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 0          2021  252.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 6          2021   22.0  Underweight Range
# 5          2021   26.0      Healthy Range
# 7          2021    NaN               None

# %%
df.sort_values('city', ascending=False, na_position='last', key = lambda col : col.str.lower())
# Out:
#        name   country         city  weight  height   bmi  birth year  \
# 4     PAWEL    Poland       Warsaw   102.0    1.95  26.8      1985.0
# 2      JOHN    Sweden    Stockholm    68.0    1.69  23.8      1990.0
# 1     DAVID        UK       London    78.0    1.75  25.5      1985.0
# 0  ASABENEH   Finland     Helsinki    74.0    1.73  24.7      1990.0
# 3      EYOB   Finland        Espoo   108.0    1.73  36.1      1983.0
# 6    THOMAS  Ethiopia    Bahir Dar    52.0    1.70  18.0      1999.0
# 5    MAHLET  Ethiopia  Addis Ababa    58.0    1.68  20.5      1995.0
# 7    LIDIYA       NaN          NaN     NaN     NaN   NaN         NaN
#
#    current year    age          BMI class
# 4          2021   36.0   Overweight Range
# 2          2021   31.0      Healthy Range
# 1          2021   36.0   Overweight Range
# 0          2021  252.0      Healthy Range
# 3          2021   38.0      Obesity Range
# 6          2021   22.0  Underweight Range
# 5          2021   26.0      Healthy Range
# 7          2021    NaN               None

# %%
joined_df.plot()
plt.show()

# %%
joined_df[['weight','height','bmi']].plot()
# Out:
# <AxesSubplot:>

# %%
joined_df[['weight','height']].plot(kind='scatter', x ='height',y='weight')
plt.show()

# %%
joined_df[['weight','bmi']].plot(kind='scatter', x ='weight',y='bmi', title = 'Weight Versus BMI')
plt.show()

# %%
joined_df[['weight']].plot(kind='bar')
plt.show()

# %%
joined_df[['weight']].plot(kind='hist')
plt.show()

# %%
joined_df[['weight']].hist()
plt.show()

# %%
df = pd.read_csv('./datasets/weight-height.csv')

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
# changing inch to centimenter
# pounds to killogram
df['Height in Cm'] = df['Height'].apply(lambda x : x * 2.54 )
df['Weight in Kg'] = df['Weight'].apply(lambda x : x * 0.453592 )

# %%
df
# Out:
#       Gender     Height      Weight  Height in Cm  Weight in Kg
# 0       Male  73.847017  241.893563    187.571423    109.720985
# 1       Male  68.781904  162.310473    174.706036     73.622732
# 2       Male  74.110105  212.740856    188.239668     96.497550
# 3       Male  71.730978  220.042470    182.196685     99.809504
# 4       Male  69.881796  206.349801    177.499761     93.598619
# ...      ...        ...         ...           ...           ...
# 9995  Female  66.172652  136.777454    168.078536     62.041159
# 9996  Female  67.067155  170.867906    170.350573     77.504315
# 9997  Female  63.867992  128.475319    162.224700     58.275377
# 9998  Female  69.034243  163.852461    175.346978     74.322166
# 9999  Female  61.944246  113.649103    157.338385     51.550324
#
# [10000 rows x 5 columns]

# %%
df['BMI']  = df['Weight in Kg'] / (df['Height in Cm'] * 0.01) ** 2

# %%
df
# Out:
#       Gender     Height      Weight  Height in Cm  Weight in Kg        BMI
# 0       Male  73.847017  241.893563    187.571423    109.720985  31.185761
# 1       Male  68.781904  162.310473    174.706036     73.622732  24.121044
# 2       Male  74.110105  212.740856    188.239668     96.497550  27.232906
# 3       Male  71.730978  220.042470    182.196685     99.809504  30.067059
# 4       Male  69.881796  206.349801    177.499761     93.598619  29.708033
# ...      ...        ...         ...           ...           ...        ...
# 9995  Female  66.172652  136.777454    168.078536     62.041159  21.961166
# 9996  Female  67.067155  170.867906    170.350573     77.504315  26.707835
# 9997  Female  63.867992  128.475319    162.224700     58.275377  22.143748
# 9998  Female  69.034243  163.852461    175.346978     74.322166  24.172512
# 9999  Female  61.944246  113.649103    157.338385     51.550324  20.823898
#
# [10000 rows x 6 columns]

# %%
df.corr()
# Out:
#                 Height    Weight  Height in Cm  Weight in Kg       BMI
# Height        1.000000  0.924756      1.000000      0.924756  0.669199
# Weight        0.924756  1.000000      0.924756      1.000000  0.896438
# Height in Cm  1.000000  0.924756      1.000000      0.924756  0.669199
# Weight in Kg  0.924756  1.000000      0.924756      1.000000  0.896438
# BMI           0.669199  0.896438      0.669199      0.896438  1.000000

# %%
x = df['Height in Cm']
y = df['Weight in Kg']

m, b = np.polyfit(x, y, 1)

df[['Height in Cm', 'Weight in Kg']].plot(kind='scatter', x = 'Height in Cm', y='Weight in Kg', title='Height Versus Weight')
plt.plot(x, m*x + b, c='r', linewidth=5)

plt.show()

# %%
df[['Height in Cm']].plot(kind='hist', grid=True)
plt.show()

# %%
df[['Weight in Kg']].plot(kind='hist', grid=True)
plt.show()
